# %% [markdown]
# <a href="https://colab.research.google.com/github/HaroldSthid/CodeLabSIG_Unisabana/blob/main/CajadeHerramientasGISUnificada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####@title ✏️ Caja de Herramientas GIS Unificada
# ####@markdown Este cuaderno de Colab centraliza tres tipos de análisis geoespaciales.
# ####@markdown 1. **Configuración:** Ejecuta las dos primeras celdas para instalar librerías y definir funciones.
# ####@markdown 2. **Panel de Control:** Rellena los campos en la tercera celda para tu análisis.
# ####@markdown 3. **Ejecución:** Ejecuta la celda del Panel de Control y la celda de "Ejecutar Análisis".
# ####@markdown 4. **Resultados:** Revisa el mapa y la tabla de datos generados.

# %%
# ==============================================================================
# CELDA 1: INSTALACIÓN DE LIBRERÍAS Y MONTAJE DE DRIVE
# ==============================================================================
print("Instalando librerías necesarias... (Esto puede tardar unos minutos)")
# !pip install pandas geopandas shapely requests tqdm geopy folium arcgis openpyxl -q

from google.colab import drive
import os

try:
    drive.mount('/content/drive')
    print("Google Drive montado exitosamente.")
except:
    print("Error al montar Google Drive. Asegúrate de autorizar el acceso.")
# Out:
# Instalando librerías necesarias... (Esto puede tardar unos minutos)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 738.5/738.5 kB 15.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 85.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 30.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 18.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.9 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...
